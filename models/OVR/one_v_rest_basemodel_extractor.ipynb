# %%
import numpy as np
from numpy import linalg as LA
import pandas as pd

import json
import keras
import tensorflow
import tensorflow_addons as tfa
from keras import layers, Model
from keras.models import Sequential
from keras.applications import DenseNet201
from keras.callbacks import Callback, EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score
from tqdm import tqdm
# Out:
# Using TensorFlow backend.

# %%
csv_path = './UrbanSound8K/metadata/UrbanSound8K.csv'
spec_path = "./numpySpectrograms/"
model_save_path = "ovr_basemodel_extractor"
extractor_weights_path = "basemodel-known"
test_size = 0.2
val_size = 0.2
batch_size = 32
num_classes = 5

# %%
class SpecLoader(keras.utils.Sequence):
  def __init__(self, x_set, y_set, batch_size, spec_dir):
    self.x, self.y = x_set, y_set
    self.batch_size = batch_size
    self.spec_dir = spec_dir

  def __len__(self):
    return int(np.ceil(len(self.x) / self.batch_size))

  def __getitem__(self, idx):
    batch_x = self.x[idx * self.batch_size:(idx + 1) *
    self.batch_size]
    batch_y = self.y[idx * self.batch_size:(idx + 1) *
        self.batch_size]

    batchSpecs = []
    for fileName in batch_x:
        spec = np.load(self.spec_dir + fileName + ".npy")
        batchSpecs.append(spec.transpose())
    return np.array(batchSpecs), np.array(batch_y)

# %%
data_df = pd.read_csv(csv_path)
data_df_known = data_df.loc[data_df["classID"] < num_classes]
data_df_unknown = data_df.loc[data_df["classID"] >= num_classes]

X_trainval, X_test, y_trainval, y_test = train_test_split(data_df_known['slice_file_name'].tolist(), data_df_known['classID'].tolist(), test_size=test_size, random_state = 42)

X_train, X_val, y_train, y_val = train_test_split(X_trainval, y_trainval, test_size=val_size, random_state = 42)
X_trash, X_unknown, y_trash, y_unknown = train_test_split(data_df_unknown['slice_file_name'].tolist(), data_df_unknown['classID'].tolist(), test_size=test_size, random_state = 42)
y_unknown = [num_classes] * len(y_unknown)

X_test = X_test + X_unknown
y_test = y_test + y_unknown
test_loader = SpecLoader(X_test, y_test, batch_size, spec_path)

# 2D array of loaders. Train and val loader for each known class
loaders=[]
for i in range(num_classes):
    loaders.append([])
    ovr_y_train = [1 if j == i else 0 for j in y_train]
    ovr_y_val = [1 if j == i else 0 for j in y_val]
    loaders[i].append(SpecLoader(X_train, ovr_y_train, batch_size, spec_path))
    loaders[i].append(SpecLoader(X_val, ovr_y_val, batch_size, spec_path))

# %%
densenet = DenseNet201(
            include_top=False,
            weights="imagenet",
            input_tensor=None,
            input_shape=None,
            pooling="avg")
prev_model = Sequential()
prev_model.add(densenet)
prev_model.add(layers.Dense(num_classes, activation="softmax"))
prev_model.load_weights(extractor_weights_path)
feature_extractor = prev_model.layers[0]
feature_extractor.trainable = False

# Array of models. One for each known class
models=[]
for i in range(num_classes):
    model = Sequential()
    model.add(feature_extractor)
    model.add(layers.Dense(2, activation="softmax"))
    model.summary()
    model.compile(
          optimizer="Adam",
          loss="sparse_categorical_crossentropy",
          metrics=["accuracy"])
    models.append(model)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet201 (Model)          (None, 1920)              18321984
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 3842
# =================================================================
# Total params: 18,325,826
# Trainable params: 3,842
# Non-trainable params: 18,321,984
# _________________________________________________________________
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet201 (Model)          (None, 1920)              18321984
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 3842
# =================================================================
# Total params: 18,325,826
# Trainable params: 3,842
# Non-trainable params: 18,321,984
# _________________________________________________________________
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet201 (Model)          (None, 1920)              18321984
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 3842
# =================================================================
# Total params: 18,325,826
# Trainable params: 3,842
# Non-trainable params: 18,321,984
# _________________________________________________________________
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet201 (Model)          (None, 1920)              18321984
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 3842
# =================================================================
# Total params: 18,325,826
# Trainable params: 3,842
# Non-trainable params: 18,321,984
# _________________________________________________________________
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet201 (Model)          (None, 1920)              18321984
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 3842
# =================================================================
# Total params: 18,325,826
# Trainable params: 3,842
# Non-trainable params: 18,321,984
# _________________________________________________________________

# %%
for i in range(num_classes):
    earlystopping = EarlyStopping(
                        patience=5, 
                        restore_best_weights=True)
    checkpoint = ModelCheckpoint(
                        model_save_path+str(i), 
                        monitor="val_accuracy", 
                        save_best_only=True)

    models[i].fit(x=loaders[i][0],
              validation_data=loaders[i][1],
              callbacks=[checkpoint, earlystopping],
              epochs=70,
              verbose=1
             )
# Out:
# Epoch 1/70
# 89/89 [==============================] - 32s 360ms/step - loss: 0.1207 - accuracy: 0.9502 - val_loss: 0.0064 - val_accuracy: 0.9873
# Epoch 2/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0209 - accuracy: 0.9961 - val_loss: 0.0031 - val_accuracy: 0.9873
# Epoch 3/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0154 - accuracy: 0.9972 - val_loss: 9.3250e-04 - val_accuracy: 0.9873
# Epoch 4/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0127 - accuracy: 0.9975 - val_loss: 4.4162e-04 - val_accuracy: 0.9873
# Epoch 5/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0107 - accuracy: 0.9972 - val_loss: 2.7580e-04 - val_accuracy: 0.9873
# Epoch 6/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0094 - accuracy: 0.9975 - val_loss: 1.4377e-04 - val_accuracy: 0.9859
# Epoch 7/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0087 - accuracy: 0.9975 - val_loss: 1.2792e-04 - val_accuracy: 0.9873
# Epoch 8/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0079 - accuracy: 0.9979 - val_loss: 1.2680e-04 - val_accuracy: 0.9873
# Epoch 9/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0071 - accuracy: 0.9982 - val_loss: 5.1826e-05 - val_accuracy: 0.9873
# Epoch 10/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0067 - accuracy: 0.9982 - val_loss: 8.1357e-05 - val_accuracy: 0.9887
# Epoch 11/70
# 89/89 [==============================] - 9s 100ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 5.4853e-05 - val_accuracy: 0.9887
# Epoch 12/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0061 - accuracy: 0.9982 - val_loss: 5.4567e-05 - val_accuracy: 0.9887
# Epoch 13/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0057 - accuracy: 0.9986 - val_loss: 4.5938e-05 - val_accuracy: 0.9887
# Epoch 14/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0053 - accuracy: 0.9989 - val_loss: 4.2816e-05 - val_accuracy: 0.9887
# Epoch 15/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0051 - accuracy: 0.9989 - val_loss: 3.3018e-05 - val_accuracy: 0.9887
# Epoch 16/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 8.7736e-06 - val_accuracy: 0.9873
# Epoch 17/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0044 - accuracy: 0.9996 - val_loss: 2.1766e-05 - val_accuracy: 0.9887
# Epoch 18/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0043 - accuracy: 0.9993 - val_loss: 9.0835e-06 - val_accuracy: 0.9873
# Epoch 19/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 5.1259e-06 - val_accuracy: 0.9873
# Epoch 20/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0041 - accuracy: 0.9989 - val_loss: 6.2226e-06 - val_accuracy: 0.9873
# Epoch 21/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0040 - accuracy: 0.9993 - val_loss: 5.1021e-06 - val_accuracy: 0.9887
# Epoch 22/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0038 - accuracy: 0.9993 - val_loss: 2.6941e-06 - val_accuracy: 0.9873
# Epoch 23/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0037 - accuracy: 0.9996 - val_loss: 4.2676e-06 - val_accuracy: 0.9887
# Epoch 24/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0033 - accuracy: 0.9996 - val_loss: 5.7696e-06 - val_accuracy: 0.9887
# Epoch 25/70
# 89/89 [==============================] - 9s 101ms/step - loss: 0.0034 - accuracy: 0.9996 - val_loss: 4.0531e-06 - val_accuracy: 0.9887
# Epoch 26/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0035 - accuracy: 0.9996 - val_loss: 3.0517e-06 - val_accuracy: 0.9887
# Epoch 27/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0034 - accuracy: 0.9993 - val_loss: 1.0252e-06 - val_accuracy: 0.9845
# Epoch 28/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0029 - accuracy: 0.9996 - val_loss: 2.5034e-06 - val_accuracy: 0.9887
# Epoch 29/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 2.0027e-06 - val_accuracy: 0.9887
# Epoch 30/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0029 - accuracy: 0.9993 - val_loss: 2.2411e-06 - val_accuracy: 0.9887
# Epoch 31/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0026 - accuracy: 0.9996 - val_loss: 1.5259e-06 - val_accuracy: 0.9887
# Epoch 32/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0026 - accuracy: 0.9996 - val_loss: 1.6689e-06 - val_accuracy: 0.9887
# Epoch 1/70
# 89/89 [==============================] - 25s 279ms/step - loss: 0.0585 - accuracy: 0.9767 - val_loss: 0.0520 - val_accuracy: 0.9901
# Epoch 2/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0106 - accuracy: 0.9975 - val_loss: 0.0249 - val_accuracy: 0.9915
# Epoch 3/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0076 - accuracy: 0.9979 - val_loss: 0.0106 - val_accuracy: 0.9929
# Epoch 4/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.0106 - val_accuracy: 0.9915
# Epoch 5/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.0058 - val_accuracy: 0.9929
# Epoch 6/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.0056 - val_accuracy: 0.9915
# Epoch 7/70
# 89/89 [==============================] - 9s 101ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.0057 - val_accuracy: 0.9901
# Epoch 8/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.0038 - val_accuracy: 0.9915
# Epoch 9/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.0031 - val_accuracy: 0.9915
# Epoch 10/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0027 - accuracy: 0.9996 - val_loss: 0.0014 - val_accuracy: 0.9944
# Epoch 11/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0024 - accuracy: 0.9996 - val_loss: 0.0011 - val_accuracy: 0.9944
# Epoch 12/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0024 - accuracy: 0.9996 - val_loss: 0.0019 - val_accuracy: 0.9915
# Epoch 13/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.0012 - val_accuracy: 0.9929
# Epoch 14/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.0011 - val_accuracy: 0.9915
# Epoch 15/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 0.9915
# Epoch 16/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 0.9901
# Epoch 1/70
# 89/89 [==============================] - 26s 295ms/step - loss: 0.0701 - accuracy: 0.9778 - val_loss: 0.0053 - val_accuracy: 0.9676
# Epoch 2/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0288 - accuracy: 0.9908 - val_loss: 0.0014 - val_accuracy: 0.9647
# Epoch 3/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0226 - accuracy: 0.9929 - val_loss: 4.5792e-04 - val_accuracy: 0.9647
# Epoch 4/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0202 - accuracy: 0.9940 - val_loss: 7.2947e-04 - val_accuracy: 0.9732
# Epoch 5/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0187 - accuracy: 0.9933 - val_loss: 3.4571e-04 - val_accuracy: 0.9746
# Epoch 6/70
# 89/89 [==============================] - 9s 100ms/step - loss: 0.0180 - accuracy: 0.9940 - val_loss: 1.3508e-04 - val_accuracy: 0.9647
# Epoch 7/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0171 - accuracy: 0.9933 - val_loss: 1.7234e-04 - val_accuracy: 0.9676
# Epoch 8/70
# 89/89 [==============================] - 9s 100ms/step - loss: 0.0162 - accuracy: 0.9944 - val_loss: 2.7777e-04 - val_accuracy: 0.9732
# Epoch 9/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0151 - accuracy: 0.9940 - val_loss: 1.1079e-04 - val_accuracy: 0.9704
# Epoch 10/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0152 - accuracy: 0.9944 - val_loss: 1.0736e-04 - val_accuracy: 0.9676
# Epoch 11/70
# 89/89 [==============================] - 9s 100ms/step - loss: 0.0144 - accuracy: 0.9947 - val_loss: 8.8869e-05 - val_accuracy: 0.9704
# Epoch 12/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0136 - accuracy: 0.9951 - val_loss: 1.0319e-04 - val_accuracy: 0.9718
# Epoch 13/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0137 - accuracy: 0.9944 - val_loss: 7.2088e-05 - val_accuracy: 0.9718
# Epoch 14/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0143 - accuracy: 0.9944 - val_loss: 1.4203e-04 - val_accuracy: 0.9760
# Epoch 15/70
# 89/89 [==============================] - 9s 100ms/step - loss: 0.0145 - accuracy: 0.9947 - val_loss: 5.6737e-05 - val_accuracy: 0.9732
# Epoch 16/70
# 89/89 [==============================] - 9s 100ms/step - loss: 0.0124 - accuracy: 0.9958 - val_loss: 3.9121e-05 - val_accuracy: 0.9676
# Epoch 17/70
# 89/89 [==============================] - 9s 100ms/step - loss: 0.0131 - accuracy: 0.9958 - val_loss: 8.1430e-05 - val_accuracy: 0.9746
# Epoch 18/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0113 - accuracy: 0.9965 - val_loss: 2.2036e-04 - val_accuracy: 0.9788
# Epoch 19/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0114 - accuracy: 0.9954 - val_loss: 9.6040e-05 - val_accuracy: 0.9746
# Epoch 20/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0110 - accuracy: 0.9965 - val_loss: 1.3243e-04 - val_accuracy: 0.9760
# Epoch 21/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0120 - accuracy: 0.9954 - val_loss: 1.0939e-04 - val_accuracy: 0.9788
# Epoch 1/70
# 89/89 [==============================] - 25s 275ms/step - loss: 0.1186 - accuracy: 0.9520 - val_loss: 0.0138 - val_accuracy: 0.9732
# Epoch 2/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0369 - accuracy: 0.9894 - val_loss: 0.0051 - val_accuracy: 0.9704
# Epoch 3/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0299 - accuracy: 0.9912 - val_loss: 0.0036 - val_accuracy: 0.9760
# Epoch 4/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0258 - accuracy: 0.9915 - val_loss: 0.0020 - val_accuracy: 0.9718
# Epoch 5/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0229 - accuracy: 0.9922 - val_loss: 0.0012 - val_accuracy: 0.9718
# Epoch 6/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0222 - accuracy: 0.9929 - val_loss: 0.0013 - val_accuracy: 0.9817
# Epoch 7/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0209 - accuracy: 0.9940 - val_loss: 0.0012 - val_accuracy: 0.9845
# Epoch 8/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0184 - accuracy: 0.9940 - val_loss: 4.8347e-04 - val_accuracy: 0.9690
# Epoch 9/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0187 - accuracy: 0.9936 - val_loss: 5.9802e-04 - val_accuracy: 0.9831
# Epoch 10/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0168 - accuracy: 0.9940 - val_loss: 3.1454e-04 - val_accuracy: 0.9760
# Epoch 11/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0171 - accuracy: 0.9940 - val_loss: 5.4569e-04 - val_accuracy: 0.9845
# Epoch 12/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0167 - accuracy: 0.9940 - val_loss: 2.2642e-04 - val_accuracy: 0.9732
# Epoch 13/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0150 - accuracy: 0.9947 - val_loss: 3.0976e-04 - val_accuracy: 0.9831
# Epoch 14/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0149 - accuracy: 0.9940 - val_loss: 2.0052e-04 - val_accuracy: 0.9803
# Epoch 15/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0142 - accuracy: 0.9947 - val_loss: 1.6242e-04 - val_accuracy: 0.9803
# Epoch 16/70
# 89/89 [==============================] - 9s 100ms/step - loss: 0.0142 - accuracy: 0.9951 - val_loss: 1.2787e-04 - val_accuracy: 0.9803
# Epoch 17/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0143 - accuracy: 0.9951 - val_loss: 1.3806e-04 - val_accuracy: 0.9831
# Epoch 18/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0131 - accuracy: 0.9954 - val_loss: 1.5769e-04 - val_accuracy: 0.9845
# Epoch 19/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0130 - accuracy: 0.9958 - val_loss: 1.2128e-04 - val_accuracy: 0.9817
# Epoch 20/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0115 - accuracy: 0.9965 - val_loss: 8.9732e-05 - val_accuracy: 0.9803
# Epoch 21/70
# 89/89 [==============================] - 9s 100ms/step - loss: 0.0121 - accuracy: 0.9961 - val_loss: 7.9005e-05 - val_accuracy: 0.9803
# Epoch 22/70
# 89/89 [==============================] - 9s 102ms/step - loss: 0.0113 - accuracy: 0.9961 - val_loss: 8.4725e-05 - val_accuracy: 0.9831
# Epoch 23/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0120 - accuracy: 0.9965 - val_loss: 9.9070e-05 - val_accuracy: 0.9817
# Epoch 24/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0114 - accuracy: 0.9951 - val_loss: 1.0100e-04 - val_accuracy: 0.9873
# Epoch 25/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0105 - accuracy: 0.9951 - val_loss: 7.8835e-05 - val_accuracy: 0.9831
# Epoch 26/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0107 - accuracy: 0.9965 - val_loss: 5.0542e-05 - val_accuracy: 0.9831
# Epoch 27/70
# 89/89 [==============================] - 9s 100ms/step - loss: 0.0102 - accuracy: 0.9965 - val_loss: 5.8312e-05 - val_accuracy: 0.9831
# Epoch 28/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0099 - accuracy: 0.9968 - val_loss: 5.3187e-05 - val_accuracy: 0.9831
# Epoch 29/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0092 - accuracy: 0.9972 - val_loss: 5.3235e-05 - val_accuracy: 0.9845
# Epoch 30/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0095 - accuracy: 0.9961 - val_loss: 6.4485e-05 - val_accuracy: 0.9873
# Epoch 31/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0107 - accuracy: 0.9965 - val_loss: 3.5594e-05 - val_accuracy: 0.9845
# Epoch 32/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0092 - accuracy: 0.9961 - val_loss: 2.8490e-05 - val_accuracy: 0.9831
# Epoch 33/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0082 - accuracy: 0.9982 - val_loss: 3.0397e-05 - val_accuracy: 0.9817
# Epoch 34/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0085 - accuracy: 0.9968 - val_loss: 2.5796e-05 - val_accuracy: 0.9817
# Epoch 35/70
# 89/89 [==============================] - 9s 101ms/step - loss: 0.0087 - accuracy: 0.9961 - val_loss: 2.1815e-05 - val_accuracy: 0.9831
# Epoch 36/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0083 - accuracy: 0.9968 - val_loss: 2.4962e-05 - val_accuracy: 0.9817
# Epoch 37/70
# 89/89 [==============================] - 9s 103ms/step - loss: 0.0079 - accuracy: 0.9979 - val_loss: 2.0003e-05 - val_accuracy: 0.9873
# Epoch 38/70
# 89/89 [==============================] - 10s 110ms/step - loss: 0.0088 - accuracy: 0.9965 - val_loss: 3.7239e-05 - val_accuracy: 0.9873
# Epoch 39/70
# 89/89 [==============================] - 9s 106ms/step - loss: 0.0079 - accuracy: 0.9972 - val_loss: 1.7738e-05 - val_accuracy: 0.9831
# Epoch 40/70
# 89/89 [==============================] - 9s 101ms/step - loss: 0.0075 - accuracy: 0.9982 - val_loss: 1.3494e-05 - val_accuracy: 0.9859
# Epoch 41/70
# 89/89 [==============================] - 9s 105ms/step - loss: 0.0074 - accuracy: 0.9979 - val_loss: 1.8858e-05 - val_accuracy: 0.9859
# Epoch 42/70
# 89/89 [==============================] - 10s 110ms/step - loss: 0.0077 - accuracy: 0.9968 - val_loss: 1.1515e-05 - val_accuracy: 0.9831
# Epoch 43/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0070 - accuracy: 0.9982 - val_loss: 1.0586e-05 - val_accuracy: 0.9845
# Epoch 44/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0070 - accuracy: 0.9975 - val_loss: 1.4639e-05 - val_accuracy: 0.9873
# Epoch 45/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 1.0705e-05 - val_accuracy: 0.9845
# Epoch 46/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0061 - accuracy: 0.9986 - val_loss: 1.2612e-05 - val_accuracy: 0.9831
# Epoch 47/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0064 - accuracy: 0.9979 - val_loss: 9.1552e-06 - val_accuracy: 0.9831
# Epoch 48/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0065 - accuracy: 0.9975 - val_loss: 9.0598e-06 - val_accuracy: 0.9873
# Epoch 49/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0070 - accuracy: 0.9975 - val_loss: 7.0095e-06 - val_accuracy: 0.9845
# Epoch 50/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0059 - accuracy: 0.9975 - val_loss: 8.0346e-06 - val_accuracy: 0.9859
# Epoch 51/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0073 - accuracy: 0.9968 - val_loss: 6.3180e-06 - val_accuracy: 0.9817
# Epoch 52/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0059 - accuracy: 0.9982 - val_loss: 4.9829e-06 - val_accuracy: 0.9859
# Epoch 53/70
# 89/89 [==============================] - 9s 100ms/step - loss: 0.0058 - accuracy: 0.9975 - val_loss: 1.2326e-05 - val_accuracy: 0.9873
# Epoch 54/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0055 - accuracy: 0.9979 - val_loss: 6.5803e-06 - val_accuracy: 0.9859
# Epoch 55/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0052 - accuracy: 0.9986 - val_loss: 7.0094e-06 - val_accuracy: 0.9803
# Epoch 56/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0050 - accuracy: 0.9986 - val_loss: 4.7922e-06 - val_accuracy: 0.9817
# Epoch 57/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0053 - accuracy: 0.9989 - val_loss: 2.8849e-06 - val_accuracy: 0.9831
# Epoch 58/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0047 - accuracy: 0.9979 - val_loss: 3.5763e-06 - val_accuracy: 0.9831
# Epoch 59/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0044 - accuracy: 0.9986 - val_loss: 3.6239e-06 - val_accuracy: 0.9859
# Epoch 60/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0045 - accuracy: 0.9989 - val_loss: 3.4571e-06 - val_accuracy: 0.9803
# Epoch 61/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0050 - accuracy: 0.9989 - val_loss: 3.0279e-06 - val_accuracy: 0.9859
# Epoch 62/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0047 - accuracy: 0.9989 - val_loss: 2.8133e-06 - val_accuracy: 0.9831
# Epoch 63/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 2.2650e-06 - val_accuracy: 0.9859
# Epoch 64/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0041 - accuracy: 0.9986 - val_loss: 1.9312e-06 - val_accuracy: 0.9845
# Epoch 65/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 2.0981e-06 - val_accuracy: 0.9845
# Epoch 66/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 1.8597e-06 - val_accuracy: 0.9831
# Epoch 67/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0035 - accuracy: 0.9993 - val_loss: 1.5974e-06 - val_accuracy: 0.9845
# Epoch 68/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0037 - accuracy: 0.9993 - val_loss: 1.4067e-06 - val_accuracy: 0.9845
# Epoch 69/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0048 - accuracy: 0.9982 - val_loss: 3.3617e-06 - val_accuracy: 0.9845
# Epoch 70/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0041 - accuracy: 0.9993 - val_loss: 1.2159e-06 - val_accuracy: 0.9859
# Epoch 1/70
# 89/89 [==============================] - 25s 276ms/step - loss: 0.1386 - accuracy: 0.9499 - val_loss: 0.0384 - val_accuracy: 0.9873
# Epoch 2/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0192 - accuracy: 0.9979 - val_loss: 0.0224 - val_accuracy: 0.9859
# Epoch 3/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0131 - accuracy: 0.9979 - val_loss: 0.0137 - val_accuracy: 0.9859
# Epoch 4/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0102 - accuracy: 0.9979 - val_loss: 0.0113 - val_accuracy: 0.9859
# Epoch 5/70
# 89/89 [==============================] - 9s 100ms/step - loss: 0.0085 - accuracy: 0.9989 - val_loss: 0.0078 - val_accuracy: 0.9845
# Epoch 6/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0073 - accuracy: 0.9986 - val_loss: 0.0072 - val_accuracy: 0.9845
# Epoch 7/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0064 - accuracy: 0.9989 - val_loss: 0.0056 - val_accuracy: 0.9859
# Epoch 8/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0059 - accuracy: 0.9989 - val_loss: 0.0057 - val_accuracy: 0.9873
# Epoch 9/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0052 - accuracy: 0.9989 - val_loss: 0.0040 - val_accuracy: 0.9859
# Epoch 10/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0049 - accuracy: 0.9993 - val_loss: 0.0041 - val_accuracy: 0.9873
# Epoch 11/70
# 89/89 [==============================] - 9s 100ms/step - loss: 0.0045 - accuracy: 0.9993 - val_loss: 0.0032 - val_accuracy: 0.9859
# Epoch 12/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0044 - accuracy: 0.9993 - val_loss: 0.0031 - val_accuracy: 0.9859
# Epoch 13/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.0027 - val_accuracy: 0.9859
# Epoch 14/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0036 - accuracy: 0.9993 - val_loss: 0.0023 - val_accuracy: 0.9859
# Epoch 15/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.0020 - val_accuracy: 0.9859
# Epoch 16/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.0018 - val_accuracy: 0.9859
# Epoch 17/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.0017 - val_accuracy: 0.9859
# Epoch 18/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0027 - accuracy: 0.9996 - val_loss: 0.0019 - val_accuracy: 0.9859
# Epoch 19/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.0014 - val_accuracy: 0.9859
# Epoch 20/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0013 - val_accuracy: 0.9845
# Epoch 21/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.0012 - val_accuracy: 0.9859
# Epoch 22/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.0011 - val_accuracy: 0.9859
# Epoch 23/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.0010 - val_accuracy: 0.9859
# Epoch 24/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 9.6297e-04 - val_accuracy: 0.9859
# Epoch 25/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 9.2369e-04 - val_accuracy: 0.9845
# Epoch 26/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0019 - accuracy: 0.9993 - val_loss: 8.5676e-04 - val_accuracy: 0.9845
# Epoch 27/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 7.5781e-04 - val_accuracy: 0.9859
# Epoch 28/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 8.9889e-04 - val_accuracy: 0.9845
# Epoch 29/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 6.6828e-04 - val_accuracy: 0.9873
# Epoch 30/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0017 - accuracy: 0.9993 - val_loss: 6.2353e-04 - val_accuracy: 0.9859
# Epoch 31/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0016 - accuracy: 0.9993 - val_loss: 6.4645e-04 - val_accuracy: 0.9845
# Epoch 32/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 7.9236e-04 - val_accuracy: 0.9873
# Epoch 33/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0015 - accuracy: 0.9993 - val_loss: 7.7157e-04 - val_accuracy: 0.9859
# Epoch 34/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0016 - accuracy: 0.9993 - val_loss: 5.8141e-04 - val_accuracy: 0.9845
# Epoch 35/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 6.5732e-04 - val_accuracy: 0.9873
# Epoch 36/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0013 - accuracy: 0.9993 - val_loss: 5.2587e-04 - val_accuracy: 0.9859
# Epoch 37/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 5.8404e-04 - val_accuracy: 0.9873
# Epoch 38/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 5.2514e-04 - val_accuracy: 0.9873
# Epoch 39/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 5.5877e-04 - val_accuracy: 0.9859
# Epoch 40/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 4.4243e-04 - val_accuracy: 0.9859
# Epoch 41/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0012 - accuracy: 0.9993 - val_loss: 4.0642e-04 - val_accuracy: 0.9859
# Epoch 42/70
# 89/89 [==============================] - 9s 98ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 4.5301e-04 - val_accuracy: 0.9845
# Epoch 43/70
# 89/89 [==============================] - 9s 99ms/step - loss: 9.4030e-04 - accuracy: 1.0000 - val_loss: 3.4374e-04 - val_accuracy: 0.9859
# Epoch 44/70
# 89/89 [==============================] - 9s 98ms/step - loss: 8.5171e-04 - accuracy: 1.0000 - val_loss: 3.4897e-04 - val_accuracy: 0.9873
# Epoch 45/70
# 89/89 [==============================] - 9s 99ms/step - loss: 0.0010 - accuracy: 0.9996 - val_loss: 4.1691e-04 - val_accuracy: 0.9845
# Epoch 46/70
# 89/89 [==============================] - 9s 99ms/step - loss: 8.3006e-04 - accuracy: 1.0000 - val_loss: 4.4595e-04 - val_accuracy: 0.9859
# Epoch 47/70
# 89/89 [==============================] - 9s 98ms/step - loss: 8.3147e-04 - accuracy: 1.0000 - val_loss: 4.3919e-04 - val_accuracy: 0.9859
# Epoch 48/70
# 89/89 [==============================] - 9s 99ms/step - loss: 8.0786e-04 - accuracy: 1.0000 - val_loss: 3.7112e-04 - val_accuracy: 0.9873

# %%
def evaluate(predicted, expected):
    acc = np.mean(np.array(predicted) == np.array(expected))
    print("Overall accuracy: {}".format(acc))
    acc_dict = {}
    for i in range(len(expected)):
        expected_class = expected[i]
        if expected_class not in acc_dict:
            acc_dict[expected_class] = [0, 0]
        acc_dict[expected_class][1] += 1
        if expected_class == predicted[i]:
            acc_dict[expected_class][0] += 1
    for k,v in acc_dict.items():
        print("Accuracy for class {}: {}".format(k, v[0]/v[1]))
    for average in ["macro", "weighted", "micro"]:
        f1 = f1_score(expected, predicted, average=average)
        print("{} f1 score: {}".format(average, f1))

# %%
for i in range(num_classes):
    models[i].load_weights(model_save_path+str(i))

# %%
y_predicted = []
y_random = []
for data, labels in tqdm(test_loader):
    for i in range(len(data)):
        probabilities = []
        for j in range(num_classes):
            probabilities.append(models[j].predict(x=np.array([data[i]]))[0][1])
        best_class = np.argmax(probabilities)
        highest_prob = probabilities[best_class]
        if highest_prob < 0.5:
            y_predicted.append(num_classes)
        else:
            y_predicted.append(best_class)
        y_random.append(np.random.randint(6))
# Out:
# 100%|██████████| 55/55 [06:51<00:00,  7.48s/it]

# %%
evaluate(y_predicted, y_test)
evaluate(y_random, y_test)
# Out:
# Overall accuracy: 0.5924441900400687
# Accuracy for class 2: 0.9605911330049262
# Accuracy for class 4: 0.9767441860465116
# Accuracy for class 0: 0.9665071770334929
# Accuracy for class 3: 0.8903508771929824
# Accuracy for class 1: 0.9864864864864865
# Accuracy for class 5: 0.22531939605110338
# macro f1 score: 0.647683959407468
# weighted f1 score: 0.5372796523877724
# micro f1 score: 0.5924441900400687
# Overall accuracy: 0.17515741270749857
# Accuracy for class 2: 0.21182266009852216
# Accuracy for class 4: 0.18023255813953487
# Accuracy for class 0: 0.11961722488038277
# Accuracy for class 3: 0.17543859649122806
# Accuracy for class 1: 0.17567567567567569
# Accuracy for class 5: 0.17886178861788618
# macro f1 score: 0.149865961765545
# weighted f1 score: 0.19862234667833067
# micro f1 score: 0.17515741270749857
